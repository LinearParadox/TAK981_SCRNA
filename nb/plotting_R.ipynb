# %%
library(schard)
library(Seurat)
setwd("/data/TAK_981")
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t

# %%
adata <-schard::h5ad2seurat('h5ad/batch_corrected.h5ad', use.raw = TRUE)

# %%
DimPlot(adata, group.by="annot") | DimPlot(adata, group.by="condition")
ggsave("figs/umap_cond_and_annot.png", width=15, height=8)
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
#
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# Error in ggsave("figs/umap_cond_and_annot.png", width = 15, height = 8): could not find function "ggsave"
# Traceback:
# plot without title
